# %%
import dramlib

folder = '/home/luismendes/DRAM-Research/test_1/'
input_files_folder = join(folder, 'params_2/')
input_files = [
  join(input_files_folder, file) 
  for file in listdir(input_files_folder)
]
paths_file = join(folder, 'paths_test_1.json')
paths_file, input_files
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 import dramlib
#       3 folder = '/home/luismendes/DRAM-Research/test_1/'
#       4 input_files_folder = join(folder, 'params_2/')
#
# ModuleNotFoundError: No module named 'dramlib'

# %%
def start(input_file, path_file):
    dcf = DRAMConfigFile()
    dcf.start(input_file, path_file)
    default_file = dcf.save_defaults()
    main_file, file_list = dcf.save()
    return default_file, main_file, file_list

# %%
def run_cnn(file_path):
    dcf = DRAMConfigFile()
    dcf.read_config(file_path)
    data = dcf.get_cnn_data()

    path        = data['path_to_cnn_conv']
    app         = data['app']
    variable    = dcf.variable_map(data['variable'])
    value       = data['value']

    cnn = CNNConv(path, app)
    cnn.run(directives=f' {variable}={value}', debug=False)

# %%
def conv_trace(file_path):
    dcf = DRAMConfigFile()
    dcf.read_config(file_path)
    data = dcf.get_conv_data()

    dramsys_path    = data['path_to_dramsys']
    new_trace_file  = data['path_to_new_trace_file']
    old_trace_file  = data['path_to_old_trace_file']
    new_cfg_file    = data['path_to_new_cfg_file']
    old_cfg_file    = data['path_to_old_cfg_file']
    clkmhz          = data['clkMhz']

    conv = Converter(dramsys_path)
    burst_length = conv.conv(new_trace_file, old_trace_file)
    conv.create_new_config_file(
        old_cfg_file, 
        new_cfg_file, 
        new_trace_file, 
        burst_length, clkmhz
    )
    dcf.update_config_file_conv(file_path, burst_length)

# %%
def run_dramsys(file_path):
    dcf = DRAMConfigFile()
    dcf.read_config(file_path)
    data = dcf.get_dramsys_data()

    path_to_dramsys     = data['path_to_dramsys']
    prefix              = data['prefix']
    output_file         = data['output_file']
    cfg_file            = data['cfg_file']

    dsys = Dramsys(path_to_dramsys)
    dsys.run_execution(cfg_file, output_file=output_file)

# %%
def run_parser(file_path):
    dcf = DRAMConfigFile()
    dcf.read_config(file_path)
    data = dcf.get_parser_data()

    output_dramsys  = data['path_to_output_dramsys']
    output_parsed   = data['path_to_output_parsed']

    parser = DRAMParser(power=True)
    parser.parse_file(output_dramsys, output_file=output_parsed)

# %%
def group(filelist):
    dcf = DRAMConfigFile()
    dcf.group(filelist)

# %%
def plot(file):
    plotter = Plotter(file)
    plotter.plot_all()

# %%
for input_file in input_files:
    default_file, main_file, file_list = start(input_file, paths_file)
    for file in file_list:
        run_cnn(file)
        conv_trace(file)
        run_dramsys(file)
        run_parser(file)
    group(file_list)
    plot(main_file)
# Out:
# mkdir -p netgen/build
# set -o pipefail ; cmake -S netgen -B netgen/build -DCLUSTERS=8 -DUNITS=8 -DLANES=2 -DNR_RAMS=8 -DLINE_SIZE=4096 -DASSOCIATIVITY=4 -DRAM_SIZE=131072 -DCMAKE_BUILD_TYPE=Release |& tee netgen/build/cmake.log
# -- [ISS config] using VPRO_SIMULATOR_LIB_dir=/home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/../../../../TOOLS/VPRO/ISS/iss_lib
# -- [ISS config] using VPRO_AUX_LIB_dir=/home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/../../../../TOOLS/VPRO/ISS/common_lib
# -- [VPRO config] CLUSTERS=8
# -- [VPRO config] UNITS=8
# -- [VPRO config] LANES=2
# -- [VPRO config] NR_RAMS=8
# -- [VPRO config] LINE_SIZE=4096
# -- [VPRO config] ASSOCIATIVITY=4
# -- [VPRO config] RAM_SIZE=131072
# -- [cmake netgen] found CNN dconvtest1_offsetconv in /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/../nets/dconvtest1_offsetconv/src
# -- [cmake netgen] found CNN dconvtest2_deform in /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/../nets/dconvtest2_deform/src
# -- [cmake netgen] found CNN dconvtest3_conv in /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/../nets/dconvtest3_conv/src
# -- [cmake netgen] found CNN nnqtest_avgpool2d_48_80_15_psize2_pstr4_same_2360022198 in /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/../nets/nnqtest_avgpool2d_48_80_15_psize2_pstr4_same_2360022198/src
# -- [cmake netgen] found CNN nnqtest_concat_2_388_2__2_2__50_500__4_144523876 in /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/../nets/nnqtest_concat_2_388_2__2_2__50_500__4_144523876/src
# -- [cmake netgen] found CNN nnqtest_conv1d in /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/../nets/nnqtest_conv1d/src
# -- [cmake netgen] found CNN nnqtest_conv2d_1_1_12_f15_bFalse_k1_s1_same_d1_g3_None_None_pN_57360959 in /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/../nets/nnqtest_conv2d_1_1_12_f15_bFalse_k1_s1_same_d1_g3_None_None_pN_57360959/src
# -- [cmake netgen] found CNN nnqtest_conv2d_bn in /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/../nets/nnqtest_conv2d_bn/src
# -- [cmake netgen] found CNN nnqtest_conv2d_pool_relu in /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/../nets/nnqtest_conv2d_pool_relu/src
# -- [cmake netgen] found CNN nnqtest_conv2d_relu_pool in /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/../nets/nnqtest_conv2d_relu_pool/src
# -- [cmake netgen] found CNN nnqtest_dense_3_u144_bFalse_None_linear_4107377269 in /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/../nets/nnqtest_dense_3_u144_bFalse_None_linear_4107377269/src
# -- [cmake netgen] found CNN nnqtest_depthwise_conv2d_depth_multiplier in /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/../nets/nnqtest_depthwise_conv2d_depth_multiplier/src
# -- [cmake netgen] found CNN nnqtest_depthwise_conv2d_relu in /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/../nets/nnqtest_depthwise_conv2d_relu/src
# -- [cmake netgen] found CNN nnqtest_slice1d in /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/../nets/nnqtest_slice1d/src
# -- [cmake netgen] found CNN nnqtest_slice2d in /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/../nets/nnqtest_slice2d/src
# -- [cmake netgen] found CNN nnqtest_test_DepthToSpace in /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/../nets/nnqtest_test_DepthToSpace/src
# -- [cmake netgen] found CNN nnqtest_vgg16 in /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/../nets/nnqtest_vgg16/src
# -- [cmake netgen] found CNN nnqtest_zp_conv2d in /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/../nets/nnqtest_zp_conv2d/src
# -- [cmake netgen] found CNN nnqtest_zp_conv2d_relu in /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/../nets/nnqtest_zp_conv2d_relu/src
# -- [cmake netgen] found CNN testlayer in /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/../nets/testlayer/src
# -- [cmake netgen] found CNN yololite in /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/../nets/yololite/src
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/build
# set -o pipefail ; make -C netgen/build -s -j netgen |& tee netgen/build/make.log
# Consolidate compiler generated dependencies of target netgen
# [  3%] Building CXX object CMakeFiles/netgen.dir/home/luismendes/zuse_ki_avf/vpro_sys_behavioral/TOOLS/VPRO/ISS/common_lib/vpro/vpro_globals.cpp.o
# [  6%] Building CXX object CMakeFiles/netgen.dir/home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/bif/bif.cpp.o
# [ 10%] Building CXX object CMakeFiles/netgen.dir/Base/base_commands.cpp.o
# [ 13%] Building CXX object CMakeFiles/netgen.dir/Base/base_layer.cpp.o
# [ 16%] Building CXX object CMakeFiles/netgen.dir/Base/base_segmentation.cpp.o
# [ 20%] Building CXX object CMakeFiles/netgen.dir/Base/command_helpers.cpp.o
# [ 23%] Building CXX object CMakeFiles/netgen.dir/Base/layers.cpp.o
# [ 26%] Building CXX object CMakeFiles/netgen.dir/ConvSegmentationHeuristic/MaxEfficiencyCalculation.cpp.o
# [ 30%] Building CXX object CMakeFiles/netgen.dir/DMACommandExtensions/DmaClusterMixer.cpp.o
# [ 33%] Building CXX object CMakeFiles/netgen.dir/DMACommandExtensions/DmaLoopExtension.cpp.o
# [ 40%] Building CXX object CMakeFiles/netgen.dir/Layer_Concat/concat_commands.cpp.o
# [ 36%] Building CXX object CMakeFiles/netgen.dir/Layer_Concat/concat_segmentation.cpp.o
# [ 43%] Building CXX object CMakeFiles/netgen.dir/Layer_Conv/conv_commands.cpp.o
# [ 46%] Building CXX object CMakeFiles/netgen.dir/DMACommandExtensions/DmaMerger.cpp.o
# [ 50%] Building CXX object CMakeFiles/netgen.dir/Layer_Conv/conv_segmentation.cpp.o
# [ 53%] Building CXX object CMakeFiles/netgen.dir/Layer_ConvTranspose/conv_transpose_commands.cpp.o
# [ 56%] Building CXX object CMakeFiles/netgen.dir/Layer_ConvTranspose/conv_transpose_segmentation.cpp.o
# [ 60%] Building CXX object CMakeFiles/netgen.dir/Layer_DeformableConv/dconv_conv_commands.cpp.o
# [ 63%] Building CXX object CMakeFiles/netgen.dir/Layer_DeformableConv/dconv_conv_segmentation.cpp.o
# [ 66%] Building CXX object CMakeFiles/netgen.dir/Layer_DeformableConv/dconv_deform_commands.cpp.o
# [ 70%] Building CXX object CMakeFiles/netgen.dir/Layer_DeformableConv/dconv_deform_layer.cpp.o
# [ 73%] Building CXX object CMakeFiles/netgen.dir/Layer_DeformableConv/dconv_deform_segmentation.cpp.o
# [ 76%] Building CXX object CMakeFiles/netgen.dir/Layer_Depth_To_Space/depth_to_space_layer.cpp.o
# [ 80%] Building CXX object CMakeFiles/netgen.dir/Layer_Depth_To_Space/depth_to_space_commands.cpp.o
# [ 83%] Building CXX object CMakeFiles/netgen.dir/Layer_Elwise/elwise_commands.cpp.o
# [ 86%] Building CXX object CMakeFiles/netgen.dir/Layer_Depth_To_Space/depth_to_space_segmentation.cpp.o
# [ 90%] Building CXX object CMakeFiles/netgen.dir/Layer_Pooling/pooling_segmentation.cpp.o
# [ 93%] Building CXX object CMakeFiles/netgen.dir/Layer_Elwise/elwise_segmentation.cpp.o
# [ 96%] Building CXX object CMakeFiles/netgen.dir/Layer_Pooling/pooling_commands.cpp.o
# In file included from /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/Layer_Pooling/pooling_commands.cpp:3:
# /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/Layer_Pooling/pooling_layer.h: In member function ‘virtual void CNN_LAYER::Pooling::processParams()’:
# /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/Layer_Pooling/pooling_layer.h:70:17: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#    70 |                 if (ps != 1)
#       |                 ^~
# In file included from /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/./Base/command_helpers.h:4,
#                  from /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/./Base/base_layer.h:19,
#                  from /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/Layer_Pooling/pooling_layer.h:4,
#                  from /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/Layer_Pooling/pooling_commands.cpp:3:
# /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/Layer_Pooling/pooling_layer.h:72:21: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#    72 |                     assert(ps == pool_size.front() && "limited implementation (as of 2023-04-24)");
#       |                     ^~~~~~
# In file included from /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/Layer_Pooling/pooling_segmentation.cpp:1:
# /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/Layer_Pooling/pooling_layer.h: In member function ‘virtual void CNN_LAYER::Pooling::processParams()’:
# /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/Layer_Pooling/pooling_layer.h:70:17: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#    70 |                 if (ps != 1)
#       |                 ^~
# In file included from /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/./Base/command_helpers.h:4,
#                  from /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/./Base/base_layer.h:19,
#                  from /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/Layer_Pooling/pooling_layer.h:4,
#                  from /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/Layer_Pooling/pooling_segmentation.cpp:1:
# /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/Layer_Pooling/pooling_layer.h:72:21: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#    72 |                     assert(ps == pool_size.front() && "limited implementation (as of 2023-04-24)");
#       |                     ^~~~~~
# In file included from /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/Base/layers.h:20,
#                  from /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/Base/layers.cpp:10:
# /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/./Layer_Pooling/pooling_layer.h: In member function ‘virtual void CNN_LAYER::Pooling::processParams()’:
# /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/./Layer_Pooling/pooling_layer.h:70:17: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#    70 |                 if (ps != 1)
#       |                 ^~
# In file included from /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/./Base/command_helpers.h:4,
#                  from /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/./Base/base_layer.h:19,
#                  from /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/Base/layers.h:7,
#                  from /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/Base/layers.cpp:10:
# /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/./Layer_Pooling/pooling_layer.h:72:21: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#    72 |                     assert(ps == pool_size.front() && "limited implementation (as of 2023-04-24)");
#       |                     ^~~~~~
# [100%] Linking CXX static library libnetgen.a
# [100%] Built target netgen
# set -o pipefail ; make -C netgen/build -s -j yololite_gen |& tee nets/yololite/build_yololite_gen.log
# Consolidate compiler generated dependencies of target netgen
# [ 93%] Built target netgen
# Consolidate compiler generated dependencies of target yololite_gen
# [ 96%] Building CXX object CMakeFiles/yololite_gen.dir/home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/nets/yololite/src/yololite_gen.cpp.o
# In file included from /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/Base/layers.h:20,
#                  from /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/nets/yololite/src/yololite_net.h:5,
#                  from /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/nets/yololite/src/yololite_gen.cpp:2:
# /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/./Layer_Pooling/pooling_layer.h: In member function ‘virtual void CNN_LAYER::Pooling::processParams()’:
# /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/./Layer_Pooling/pooling_layer.h:70:17: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#    70 |                 if (ps != 1)
#       |                 ^~
# In file included from /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/./Base/command_helpers.h:4,
#                  from /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/./Base/base_layer.h:19,
#                  from /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/Base/layers.h:7,
#                  from /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/nets/yololite/src/yololite_net.h:5,
#                  from /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/nets/yololite/src/yololite_gen.cpp:2:
# /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/netgen/./Layer_Pooling/pooling_layer.h:72:21: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#    72 |                     assert(ps == pool_size.front() && "limited implementation (as of 2023-04-24)");
#       |                     ^~~~~~
# [100%] Linking CXX executable yololite_gen
# [100%] Built target yololite_gen
#
# [make] build_yololite_gen SUCCESS
# == Running yololite_gen
# set -o pipefail ; cd nets/yololite && ../../netgen/build/yololite_gen |& tee run_yololite_gen.log
# FIXME clamping segmentation to 28x28 for yololite special case; pooling is broken for larger sizes
# Eval for inx = 7, iny = 7, [in size = 49], inc = 256, outc = 125. HW parallel Lanes: 128
# Remaining:   574 Configuration for Evaluation
# All Evaluations Done!
#   Best Result: (n 1, m 1, bs 49, bc 1, eff 54.875645)
#   Original Eff: 54.88
#   Efficiency Improvement: +0.00% [After 574 evaluations]
# VPRO memory blocks: (details see init/input.cfg + exit/output.cfg)
#   0x81000000 .. 0x8110d6d9 (   1103578 byte): CNN input + layer outputs
#   0xa0000000 .. 0xa0117739 (   1144634 byte): weights
# =================== Frontend-dump 'YOLO-LITE' ===================
# == Layer 'input' (-1) I, class Input
#   src : -
#   dest: { 'Layer_0 CONV2+BIAS+RELU' (0) } : whc 224x224x3, mem 224x224x3 @ 0x81000000, allocated 301056 byte @ 0x81000000 .. 0x810497ff
#   padding: algo trbl 0, 0, 0, 0; dma 0, 0, 0, 0
#   segmentation: count wh 1x1, in: size 0x0, stride 0x0, out: size 224x224, stride 224x224
#   parallel channels per lane: in 1, out 1
#   groups: -2147483648 ->, out_group_len: 0
# == Layer 'Layer_0 CONV2+BIAS+RELU' (0), class Conv2D
#   Last layer reading CNN input
#   src : { 'input' (-1): whc 224x224x3, mem 224x224x3 @ 0x81000000 }
#   dest: { 'Layer_1 CONV2+BIAS+RELU' (1) } : whc 112x112x16, mem 112x112x16 @ 0x81049800, allocated 401408 byte @ 0x81049800 .. 0x810ab7ff
#   padding: algo trbl 1, 1, 1, 1; dma 1, 1, 1, 1
#   segmentation: count wh 8x8, in: size 30x30, stride 28x28, out: size 28x28, stride 14x14
#   parallel channels per lane: in 1, out 1
#   groups: 1 -> in_group_len(0): 3, out_group_len: 16
#   weights: 'weights/l000_weights.bin' (loaded), int16[448]
#   padding_mode same, kernel 3x3, stride 1, dilation rate 1x1 -> dilated kernel 3x3, conv_out_dim 224x224
#   pool_size 2, pool_after_activation 0, activation LEAKY
# == Layer 'Layer_1 CONV2+BIAS+RELU' (1), class Conv2D
#   src : { 'Layer_0 CONV2+BIAS+RELU' (0): whc 112x112x16, mem 112x112x16 @ 0x81049800 }
#   dest: { 'Layer_2 CONV2+BIAS+RELU' (2) } : whc 56x56x32, mem 56x56x32 @ 0x810ab800, allocated 200704 byte @ 0x810ab800 .. 0x810dc7ff
#   padding: algo trbl 1, 1, 1, 1; dma 1, 1, 1, 1
#   segmentation: count wh 4x4, in: size 30x30, stride 28x28, out: size 28x28, stride 14x14
#   parallel channels per lane: in 1, out 1
#   groups: 1 -> in_group_len(0): 16, out_group_len: 32
#   weights: 'weights/l001_weights.bin' (loaded), int16[4640]
#   padding_mode same, kernel 3x3, stride 1, dilation rate 1x1 -> dilated kernel 3x3, conv_out_dim 112x112
#   pool_size 2, pool_after_activation 0, activation LEAKY
# == Layer 'Layer_2 CONV2+BIAS+RELU' (2), class Conv2D
#   src : { 'Layer_1 CONV2+BIAS+RELU' (1): whc 56x56x32, mem 56x56x32 @ 0x810ab800 }
#   dest: { 'Layer_3 CONV2+BIAS+RELU' (3) } : whc 28x28x64, mem 28x28x64 @ 0x810dc800, allocated 100352 byte @ 0x810dc800 .. 0x810f4fff
#   padding: algo trbl 1, 1, 1, 1; dma 1, 1, 1, 1
#   segmentation: count wh 2x2, in: size 30x30, stride 28x28, out: size 28x28, stride 14x14
#   parallel channels per lane: in 1, out 1
#   groups: 1 -> in_group_len(0): 32, out_group_len: 64
#   weights: 'weights/l002_weights.bin' (loaded), int16[18496]
#   padding_mode same, kernel 3x3, stride 1, dilation rate 1x1 -> dilated kernel 3x3, conv_out_dim 56x56
#   pool_size 2, pool_after_activation 0, activation LEAKY
# == Layer 'Layer_3 CONV2+BIAS+RELU' (3), class Conv2D
#   src : { 'Layer_2 CONV2+BIAS+RELU' (2): whc 28x28x64, mem 28x28x64 @ 0x810dc800 }
#   dest: { 'Layer_4 CONV2+BIAS+RELU' (4) } : whc 14x14x128, mem 14x14x128 @ 0x810f5000, allocated 50176 byte @ 0x810f5000 .. 0x811013ff
#   padding: algo trbl 1, 1, 1, 1; dma 1, 1, 1, 1
#   segmentation: count wh 1x1, in: size 30x30, stride 28x28, out: size 28x28, stride 14x14
#   parallel channels per lane: in 1, out 1
#   groups: 1 -> in_group_len(0): 64, out_group_len: 128
#   weights: 'weights/l003_weights.bin' (loaded), int16[73856]
#   padding_mode same, kernel 3x3, stride 1, dilation rate 1x1 -> dilated kernel 3x3, conv_out_dim 28x28
#   pool_size 2, pool_after_activation 0, activation LEAKY
# == Layer 'Layer_4 CONV2+BIAS+RELU' (4), class Conv2D
#   src : { 'Layer_3 CONV2+BIAS+RELU' (3): whc 14x14x128, mem 14x14x128 @ 0x810f5000 }
#   dest: { 'Layer_5 CONV2+BIAS+RELU' (5) } : whc 7x7x128, mem 7x7x128 @ 0x81101400, allocated 12544 byte @ 0x81101400 .. 0x811044ff
#   padding: algo trbl 1, 1, 1, 1; dma 1, 1, 1, 1
#   segmentation: count wh 1x1, in: size 16x16, stride 14x14, out: size 14x14, stride 7x7
#   parallel channels per lane: in 1, out 1
#   groups: 1 -> in_group_len(0): 128, out_group_len: 128
#   weights: 'weights/l004_weights.bin' (loaded), int16[147584]
#   padding_mode same, kernel 3x3, stride 1, dilation rate 1x1 -> dilated kernel 3x3, conv_out_dim 14x14
#   pool_size 2, pool_after_activation 0, activation LEAKY
# == Layer 'Layer_5 CONV2+BIAS+RELU' (5), class Conv2D
#   src : { 'Layer_4 CONV2+BIAS+RELU' (4): whc 7x7x128, mem 7x7x128 @ 0x81101400 }
#   dest: { 'Layer_6 CONV2+BIAS+NONE' (6) } : whc 7x7x256, mem 7x7x256 @ 0x81104500, allocated 25088 byte @ 0x81104500 .. 0x8110a6ff
#   padding: algo trbl 1, 1, 1, 1; dma 1, 1, 1, 1
#   segmentation: count wh 1x1, in: size 9x9, stride 7x7, out: size 7x7, stride 7x7
#   parallel channels per lane: in 1, out 1
#   groups: 1 -> in_group_len(0): 128, out_group_len: 256
#   weights: 'weights/l005_weights.bin' (loaded), int16[295168]
#   padding_mode same, kernel 3x3, stride 1, dilation rate 1x1 -> dilated kernel 3x3, conv_out_dim 7x7
#   pool_size 1, pool_after_activation 0, activation LEAKY
# == Layer 'Layer_6 CONV2+BIAS+NONE' (6) O, class Conv2D
#   First layer writing CNN output
#   src : { 'Layer_5 CONV2+BIAS+RELU' (5): whc 7x7x256, mem 7x7x256 @ 0x81104500 }
#   dest: <Result> : whc 7x7x125, mem 7x7x125 @ 0x8110a700, allocated 12250 byte @ 0x8110a700 .. 0x8110d6d9
#   padding: algo trbl 0, 0, 0, 0; dma 0, 0, 0, 0
#   segmentation: count wh 1x1, in: size 7x7, stride 7x7, out: size 7x7, stride 7x7
#   parallel channels per lane: in 1, out 1
#   groups: 1 -> in_group_len(0): 256, out_group_len: 125
#   weights: 'weights/l006_weights.bin' (loaded), int16[32125]
#   padding_mode same, kernel 1x1, stride 1, dilation rate 1x1 -> dilated kernel 1x1, conv_out_dim 7x7
#   pool_size 1, pool_after_activation 0, activation NONE
# =================== EISV blob generation 'YOLO-LITE' ===================
# == Layer 'Layer_0 CONV2+BIAS+RELU' (0)
#   [Segment Mapping | Unit Broadcasting] 5386 Commands (double buffering: DMA/VPRO/Sync)
#   [DMA Block Extraction | Cluster Broadcasting] 25 DMA Blocks
#       1827 Commands total (-3584 DMA Commands by Cluster Broadcasting; -66.24%)
#   [DMA CMD LOOP] Direct DMA commands remaining (no loop): 147, Loop encoded DMA commands: 1680, number of DMA Loops: 184 (+VPRO/Syncs)
#       515 Commands in total (-1312 Commands by Loop; -71.81%)
# set   0 [FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF]
# set   1 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set   2 [LLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLL]
# set   3 [FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF]
# set   4 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set   5 [LLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLL]
# set   6 [FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF]
# set   7 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set   8 [LLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLL]
# set   9 [FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF]
# set  10 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  11 [LLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLL]
# set  12 [FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF]
# set  13 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  14 [LLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLL]
# set  15 [FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF]
# set  16 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  17 [LLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLL]
# set  18 [FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF]
# set  19 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  20 [LLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLL]
# set  21 [FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF]
# set  22 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  23 [LLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLL]
#     3072 segments ->    515 commands,    16672 byte total
# == Layer 'Layer_1 CONV2+BIAS+RELU' (1)
#   [Segment Mapping | Unit Broadcasting] 9870 Commands (double buffering: DMA/VPRO/Sync)
#   [DMA Block Extraction | Cluster Broadcasting] 65 DMA Blocks
#       3151 Commands total (-6784 DMA Commands by Cluster Broadcasting; -68.28%)
#   [DMA CMD LOOP] Direct DMA commands remaining (no loop): 335, Loop encoded DMA commands: 2176, number of DMA Loops: 68 (+VPRO/Syncs)
#       1111 Commands in total (-2040 Commands by Loop; -64.74%)
# set   0 [FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF]
# set   1 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set   2 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set   3 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set   4 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set   5 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set   6 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set   7 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set   8 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set   9 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  10 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  11 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  12 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  13 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  14 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  15 [LLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLL]
# set  16 [FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF]
# set  17 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  18 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  19 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  20 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  21 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  22 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  23 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  24 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  25 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  26 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  27 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  28 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  29 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  30 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  31 [LLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLL]
# set  32 [FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF]
# set  33 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  34 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  35 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  36 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  37 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  38 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  39 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  40 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  41 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  42 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  43 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  44 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  45 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  46 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  47 [LLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLL]
# set  48 [FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF]
# set  49 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  50 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  51 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  52 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  53 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  54 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  55 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  56 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  57 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  58 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  59 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  60 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  61 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  62 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  63 [LLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLL]
#     8192 segments ->   1111 commands,    35744 byte total
# == Layer 'Layer_2 CONV2+BIAS+RELU' (2)
#   [Segment Mapping | Unit Broadcasting] 9352 Commands (double buffering: DMA/VPRO/Sync)
#   [DMA Block Extraction | Cluster Broadcasting] 65 DMA Blocks
#       4809 Commands total (-4608 DMA Commands by Cluster Broadcasting; -48.93%)
#   [DMA CMD LOOP] Direct DMA commands remaining (no loop): 329, Loop encoded DMA commands: 4224, number of DMA Loops: 66 (+VPRO/Syncs)
#       717 Commands in total (-4092 Commands by Loop; -85.09%)
# set   0 [FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF]
# set   1 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set   2 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set   3 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set   4 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set   5 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set   6 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set   7 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set   8 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set   9 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  10 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  11 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  12 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  13 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  14 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  15 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  16 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  17 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  18 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  19 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  20 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  21 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  22 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  23 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  24 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  25 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  26 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  27 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  28 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  29 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  30 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  31 [LLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLL]
# set  32 [FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF]
# set  33 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  34 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  35 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  36 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  37 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  38 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  39 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  40 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  41 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  42 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  43 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  44 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  45 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  46 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  47 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  48 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  49 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  50 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  51 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  52 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  53 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  54 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  55 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  56 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  57 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  58 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  59 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  60 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  61 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  62 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  63 [LLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLL]
#     8192 segments ->    717 commands,    23136 byte total
# == Layer 'Layer_3 CONV2+BIAS+RELU' (3)
#   [Segment Mapping | Unit Broadcasting] 9093 Commands (double buffering: DMA/VPRO/Sync)
#   [DMA Block Extraction | Cluster Broadcasting] 65 DMA Blocks
#       8710 Commands total (-448 DMA Commands by Cluster Broadcasting; -4.89%)
#   [DMA CMD LOOP] Direct DMA commands remaining (no loop): 262, Loop encoded DMA commands: 8448, number of DMA Loops: 66 (+VPRO/Syncs)
#       394 Commands in total (-8316 Commands by Loop; -95.48%)
# set   0 [FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF]
# set   1 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set   2 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set   3 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set   4 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set   5 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set   6 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set   7 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set   8 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set   9 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  10 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  11 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  12 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  13 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  14 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  15 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  16 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  17 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  18 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  19 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  20 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  21 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  22 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  23 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  24 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  25 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  26 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  27 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# set  28 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx]
# ...
# set 225 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 226 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 227 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 228 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 229 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 230 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 231 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 232 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 233 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 234 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 235 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 236 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 237 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 238 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 239 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 240 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 241 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 242 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 243 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 244 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 245 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 246 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 247 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 248 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 249 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 250 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 251 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 252 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 253 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 254 [xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx---]
# set 255 [LLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLL---]
#    32768 segments ->   1800 commands,    57792 byte total
# -- 8 frontend layers, 7 layers in blob, 7 layers in execlist: 0..6
#   BIF::NET           :       64 byte including BIF::LAYER offsets
#   BIF::LAYER    [  7]:   221056 byte
#   LAYER_EXECLIST[  7]:       28 byte
#   EISV_BLOB          :   221148 byte, relocatable
#
# [make] run_yololite_gen SUCCESS
# mkdir -p sim/build
# set -o pipefail ; cmake -S sim -B sim/build -DCLUSTERS=8 -DUNITS=8 -DLANES=2 -DNR_RAMS=8 -DLINE_SIZE=4096 -DASSOCIATIVITY=4 -DRAM_SIZE=131072 -DCMAKE_BUILD_TYPE=Release |& tee sim/build/cmake.log
# -- [ISS config] using VPRO_SIMULATOR_LIB_dir=/home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/sim/../../../../TOOLS/VPRO/ISS/iss_lib
# -- [ISS config] using VPRO_AUX_LIB_dir=/home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/sim/../../../../TOOLS/VPRO/ISS/common_lib
# -- [VPRO config] CLUSTERS=8
# -- [VPRO config] UNITS=8
# -- [VPRO config] LANES=2
# -- [VPRO config] NR_RAMS=8
# -- [VPRO config] LINE_SIZE=4096
# -- [VPRO config] ASSOCIATIVITY=4
# -- [VPRO config] RAM_SIZE=131072
# -- [ISS-LIB] Compile as Standalone ISS
# -- [COMMON-LIB] using SIMULATION=1
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/sim/build
# set -o pipefail ; make -C sim/build -s -j sim |& tee sim/build/make.log
# [  1%] Automatic MOC and UIC for target VPRO_SIMULATOR_LIB
# Consolidate compiler generated dependencies of target VPRO_AUX_LIB
# [  1%] Built target VPRO_SIMULATOR_LIB_autogen
# [  3%] Building CXX object VPRO_AUX_LIB/CMakeFiles/VPRO_AUX_LIB.dir/riscv/eisv_gp_registers.cpp.o
# [  5%] Building CXX object VPRO_AUX_LIB/CMakeFiles/VPRO_AUX_LIB.dir/vpro/VPRO.cpp.o
# [  7%] Building CXX object VPRO_AUX_LIB/CMakeFiles/VPRO_AUX_LIB.dir/vpro/vpro_globals.cpp.o
# Consolidate compiler generated dependencies of target VPRO_SIMULATOR_LIB
# [ 85%] Built target VPRO_SIMULATOR_LIB
# [ 87%] Linking CXX static library libVPRO_AUX_LIB.a
# [ 87%] Built target VPRO_AUX_LIB
# Consolidate compiler generated dependencies of target sim
# [ 89%] Building CXX object CMakeFiles/sim.dir/home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/bif/bif.cpp.o
# [ 91%] Building CXX object CMakeFiles/sim.dir/home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/runtime/calc_cnn.cpp.o
# [ 92%] Building CXX object CMakeFiles/sim.dir/home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/runtime/runtime.cpp.o
# [ 94%] Building CXX object CMakeFiles/sim.dir/home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/runtime/segment_scheduling.cpp.o
# [ 96%] Building CXX object CMakeFiles/sim.dir/sim.cpp.o
# [ 98%] Building CXX object CMakeFiles/sim.dir/home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/runtime/vpro_functions_statistical.cpp.o
# In file included from /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/runtime/kernels.h:16,
#                  from /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/runtime/segment_scheduling.cpp:8:
# /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/runtime/kernels/pointpillars_kernel.h: In function ‘void pointpillars(const BIF::LAYER&, const BIF::COMMAND_SEGMENT*, uint32_t)’:
# /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/runtime/kernels/pointpillars_kernel.h:188:18: warning: unused variable ‘first_block_seg’ [-Wunused-variable]
#   188 |             bool first_block_seg = true;
#       |                  ^~~~~~~~~~~~~~~
# /home/luismendes/zuse_ki_avf/vpro_sys_behavioral/APPS/EISV/cnn_converter/runtime/kernels/pointpillars_kernel.h:148:14: warning: variable ‘last_seg’ set but not used [-Wunused-but-set-variable]
#   148 |     uint32_t last_seg = 0; // index of the previous segment
#       |              ^~~~~~~~
# [100%] Linking CXX executable sim
# [100%] Built target sim
# mkdir -p nets/yololite/sim_results
# set -o pipefail ; cd nets/yololite/sim_results && ../../../sim/build/sim --windowless |& tee ../sim_yololite.log
# Gonna run silent, without windows [--windowless]
# # ---------------------------------------------------------------------------------
# # VPRO instruction set & system simulator
# # ---------------------------------------------------------------------------------
# # VPRO Array Configuration:
# #  Clusters:    8, Units (per Cl):   8, Processing Lanes (per VU):   2
# #                       Total VUs:  64, Total Processing Lanes:    128
# #
# # DCMA Configuration:
# #  #Rams:    8, Cache Line Size in Bytes:  4096,
# #                       Associativity:   4, Ram Size in Bytes:    131072
# #
# # ISS Memories:
# #  Main Memory (Non Blocking):    8-bit x 4294967296 (  4 GB)
# #  Local Memory:  16-bit x   8192
# #  Register File: 24-bit x   1024
# #
# # Clocks:
# #   Risc-V (only ISS functions calls): 200.00 MHz (5.00 ns Period)
# #   AXI (Memory Accesses):             200.00 MHz (5.00 ns Period)
# #   DCMA:                              200.00 MHz (5.00 ns Period)
# #   DMA:                               200.00 MHz (5.00 ns Period)
# #   VPRO:                              400.00 MHz (2.50 ns Period)
# #
# # ISS Tick Time Period: 2.50 ns
# # ---------------------------------------------------------------------------------
# # [NonBlockingMainMemory] Allocating memory... (Size: 4294967296 Bytes)
# # Calling initialization Script ../init/init.sh ... [Init-Script] start
# [Init-Script] done
# # Input settings from ../init/input.cfg
#
# # ISS initialized. Starting Application.
# # ---------------------------------------------------------------------------------
#
# ###############################
# Application: CNN sim, 0.1
# SW-Version:  2024-08-23 12:17:40
# HW-Version:  2024-08-23 12:17:59
# GIT Commit (ISS): c535
#
# Frequency VPRO:  400 MHz
# Frequency EIS-V: 200 MHz
# Frequency DMA:   200 MHz
# Frequency AXI:   200 MHz
# VPRO Config:
#   Clusters:                  8
#   Units per Cluster:         8
#   Proc. Lanes per Unit:      2
# DCMA Config:
# ###############################
#
# [Min Req Check Succeeds] 8 Clusters, 8 Units, 2 Lanes
# net.magicword = 4093016705
# net.blobsize = 221148
# =================== CNN execution from binary ===================
# layers = 7
# layer_execlist[  0] =   0: layer (  0), type CONV2,    515 COMMAND_SEGMENTs @ 0x7f9d883410e0
# Total Segments: 515 (515 [100.00 %, +0.00 %] with sense due to HW Configuration Overhead)
#  Commands left:      0 / 515 [############################################################] 100.0%
# [LAYER 0] took 107930 cycles
# [Clock] 107957 cycles
#
# All Cycles in EIS-V Domain (200.00 MHz):
#   [AUX Counter] (any) Lane active:                  90952 Cycles ( 84.28%)
#   [AUX Counter] (any) DMA active:                   57154 Cycles ( 52.96%)
#   [AUX Counter] (any) Lane AND (any) DMA active:    40913 Cycles ( 37.91%)
#   [AUX Counter] EISV Total:                        107905 Cycles
#   [AUX Counter] VPRO Total:                        107905 Cycles
#   [AUX Counter] Not Synchronizing VPRO:             38830 Cycles ( 35.98% Busy)
#
# DMA_ACCESS_COUNTERs in DMA Domain (200.00 MHz)
#   DMA 0, [Cycles] Read Hit 6992 Miss 6621, Write Hit 7168 Miss 8314
#   DMA 1, [Cycles] Read Hit 7606 Miss 7367, Write Hit 7168 Miss 8492
#   DMA 2, [Cycles] Read Hit 7586 Miss 7448, Write Hit 7168 Miss 8435
#   DMA 3, [Cycles] Read Hit 7581 Miss 7468, Write Hit 7168 Miss 8681
#   DMA 4, [Cycles] Read Hit 7580 Miss 7630, Write Hit 7180 Miss 8862
#   DMA 5, [Cycles] Read Hit 7658 Miss 7773, Write Hit 7168 Miss 8853
#   DMA 6, [Cycles] Read Hit 7623 Miss 7808, Write Hit 7171 Miss 8746
#   DMA 7, [Cycles] Read Hit 7098 Miss 7151, Write Hit 7188 Miss 8741
#
# Clock Domains
#   [EIS-V]: 200.00 MHz (5.00 ns Period)
#   [AXI]:   200.00 MHz (5.00 ns Period)
#   [DCMA]:  200.00 MHz (5.00 ns Period)
#   [DMA]:   200.00 MHz (5.00 ns Period)
#   [VPRO]:  400.00 MHz (2.50 ns Period)
#
# Stats have been reset befor this Layer!
# 	Risc Clock	 Layer: 107905, 	Accumulated: 107905
# layer_execlist[  1] =   1: layer (  1), type CONV2,   1111 COMMAND_SEGMENTs @ 0x7f9d88345200
# Total Segments: 1111 (1111 [100.00 %, +0.00 %] with sense due to HW Configuration Overhead)
#  Commands left:      0 / 1111 [############################################################] 100.0%
# [LAYER 1] took 350273 cycles
# [Clock] 350300 cycles
#
# All Cycles in EIS-V Domain (200.00 MHz):
#   [AUX Counter] (any) Lane active:                 231948 Cycles ( 95.75%)
#   [AUX Counter] (any) DMA active:                   57917 Cycles ( 23.91%)
#   [AUX Counter] (any) Lane AND (any) DMA active:    49505 Cycles ( 20.43%)
#   [AUX Counter] EISV Total:                        242226 Cycles
#   [AUX Counter] VPRO Total:                        242226 Cycles
#   [AUX Counter] Not Synchronizing VPRO:             95946 Cycles ( 39.61% Busy)
#
# DMA_ACCESS_COUNTERs in DMA Domain (200.00 MHz)
#   DMA 0, [Cycles] Read Hit 18240 Miss 96, Write Hit 3584 Miss 2434
#   DMA 1, [Cycles] Read Hit 18240 Miss 265, Write Hit 3584 Miss 2644
#   DMA 2, [Cycles] Read Hit 20119 Miss 1994, Write Hit 3584 Miss 2462
#   DMA 3, [Cycles] Read Hit 20118 Miss 2228, Write Hit 3586 Miss 2670
#   DMA 4, [Cycles] Read Hit 20121 Miss 2004, Write Hit 3586 Miss 2448
#   DMA 5, [Cycles] Read Hit 20098 Miss 2245, Write Hit 3588 Miss 2677
#   DMA 6, [Cycles] Read Hit 18251 Miss 1972, Write Hit 3585 Miss 2466
#   DMA 7, [Cycles] Read Hit 18257 Miss 2214, Write Hit 3596 Miss 2716
#
# Clock Domains
#   [EIS-V]: 200.00 MHz (5.00 ns Period)
#   [AXI]:   200.00 MHz (5.00 ns Period)
#   [DCMA]:  200.00 MHz (5.00 ns Period)
#   [DMA]:   200.00 MHz (5.00 ns Period)
#   [VPRO]:  400.00 MHz (2.50 ns Period)
#
# Stats have been reset befor this Layer!
# 	Risc Clock	 Layer: 242226, 	Accumulated: 350131
# layer_execlist[  2] =   2: layer (  2), type CONV2,    717 COMMAND_SEGMENTs @ 0x7f9d8834dda0
# Total Segments: 717 (717 [100.00 %, +0.00 %] with sense due to HW Configuration Overhead)
#  Commands left:      0 / 717 [############################################################] 100.0%
# [LAYER 2] took 589531 cycles
# [Clock] 589558 cycles
#
# All Cycles in EIS-V Domain (200.00 MHz):
#   [AUX Counter] (any) Lane active:                 230726 Cycles ( 96.48%)
#   [AUX Counter] (any) DMA active:                   51304 Cycles ( 21.45%)
#   [AUX Counter] (any) Lane AND (any) DMA active:    44769 Cycles ( 18.72%)
#   [AUX Counter] EISV Total:                        239141 Cycles
#   [AUX Counter] VPRO Total:                        239141 Cycles
#   [AUX Counter] Not Synchronizing VPRO:             95084 Cycles ( 39.76% Busy)
#
# DMA_ACCESS_COUNTERs in DMA Domain (200.00 MHz)
#   DMA 0, [Cycles] Read Hit 17952 Miss 378, Write Hit 1792 Miss 480
#   DMA 1, [Cycles] Read Hit 17953 Miss 594, Write Hit 1792 Miss 674
#   DMA 2, [Cycles] Read Hit 17953 Miss 903, Write Hit 1792 Miss 871
#   DMA 3, [Cycles] Read Hit 17952 Miss 1372, Write Hit 1792 Miss 1152
#   DMA 4, [Cycles] Read Hit 17956 Miss 2366, Write Hit 1792 Miss 593
#   DMA 5, [Cycles] Read Hit 17957 Miss 2623, Write Hit 1792 Miss 777
#   DMA 6, [Cycles] Read Hit 17955 Miss 2849, Write Hit 1797 Miss 928
#   DMA 7, [Cycles] Read Hit 17955 Miss 3327, Write Hit 1801 Miss 1229
#
# Clock Domains
#   [EIS-V]: 200.00 MHz (5.00 ns Period)
#   [AXI]:   200.00 MHz (5.00 ns Period)
#   [DCMA]:  200.00 MHz (5.00 ns Period)
#   [DMA]:   200.00 MHz (5.00 ns Period)
#   [VPRO]:  400.00 MHz (2.50 ns Period)
#
# Stats have been reset befor this Layer!
# 	Risc Clock	 Layer: 239141, 	Accumulated: 589272
# layer_execlist[  3] =   3: layer (  3), type CONV2,    394 COMMAND_SEGMENTs @ 0x7f9d88353800
# Total Segments: 394 (394 [100.00 %, +0.00 %] with sense due to HW Configuration Overhead)
#  Commands left:     16 / 394 [##########################################################  ]  95.9%
